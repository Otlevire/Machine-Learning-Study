# %% [markdown]
# <a href="https://colab.research.google.com/github/Otlevire/Machine-Learning-Study/blob/main/ML2_Introdu%C3%A7%C3%A3o_Classifica%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri='https://gist.githubusercontent.com/guilhermesilveira/2d2efa37d66b6c84a722ea627a897ced/raw/10968b997d885cbded1c92938c7a9912ba41c615/tracking.csv'
dados = pd.read_csv(uri)
dados.head()
# Out:
#    home  how_it_works  contact  bought
# 0     1             1        0       0
# 1     1             1        0       0
# 2     1             1        0       0
# 3     1             1        0       0
# 4     1             1        0       0

# %%
mapa = {
    "home": "principal",
    "how_it_works": "como_funciona",
    "contact": "contacto",
    "bought": "comprou"
}
dados = dados.rename(columns=mapa)

# %%
x = dados[['principal', 'como_funciona', 'contacto']]
y = dados[['comprou']]
y.head()
# Out:
#    comprou
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %%
dados.shape
# Out:
# (99, 4)

# %%
# separando dados de treino 75% dos dados
# e 25% dos dados para teste

treino_x = x[:75]
treino_y = y[:75]
teste_x = x[75:]
teste_y = y[75:]

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

modelo = LinearSVC()
modelo.fit(treino_x, treino_y)
previsoes = modelo.predict(teste_x)
acuracia = accuracy_score(teste_y, previsoes)
print('A taxa de acerto é de:%.2f%%' % (acuracia*100))
# Out:
# A taxa de acerto é de:95.83%
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
